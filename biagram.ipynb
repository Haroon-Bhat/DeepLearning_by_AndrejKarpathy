# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?
max_iters = 3000
eval_interval = 300
learning_rate = 1e-2
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        logits = self.token_embedding_table(idx) # (B,T,C)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# step 0: train loss 4.7305, val loss 4.7241
# step 300: train loss 2.8110, val loss 2.8249
# step 600: train loss 2.5434, val loss 2.5682
# step 900: train loss 2.4932, val loss 2.5088
# step 1200: train loss 2.4863, val loss 2.5035
# step 1500: train loss 2.4665, val loss 2.4921
# step 1800: train loss 2.4683, val loss 2.4936
# step 2100: train loss 2.4696, val loss 2.4846
# step 2400: train loss 2.4638, val loss 2.4879
# step 2700: train loss 2.4738, val loss 2.4911
#
# MARI he avayokis erceller thour d, myono thishe me tord se by he me, Forder anen: at trselorinjulour t yoru thrd wo ththathy IUShe bavidelanoby man ond be jus as g e atot Meste hrle s, ppat t JLENCOLIUS:
# Oppid tes d s o ged moer y pevehear soue maramapay fo t: bueyo malalyo!
# Duir.
# Fl ke it I t l o'ddre d ondu s?
# cr, havetrathackes w.
# PUpee meshancun, hrendspouthoulouren whel's'sesoread pe, s whure our heredinsethes; sedsend r lo pamit,
# QUMIVIVIOfe m ne RDINid we tr ort; t:
# MINENXI l dintandore r

# %%
# make the predictions about what comes next so now these uh now these tokens have to start talking to each other and figuring out what is in the context so that they can make better predictions for what comes next and this is how we're going to kick off the uh Transformer okay so next I took the code that we developed in this juper notebook and I converted it to be a script and I'm doing this because I just want to simplify our intermediate work into just the final product that we have at this
# point so in the top here I put all the hyp parameters that we to find I introduced a few and I'm going to speak to that in a little bit otherwise a lot of this should be recognizable uh reproducibility read data get the encoder and the decoder create the train into splits uh use the uh kind of like data loader um that gets a batch of the inputs and Targets this is new and I'll talk about it in a second now this is the Byram language model that we developed and it can forward and give us
# a logits and loss and it can generate and then here we are creating the optimizer and this is the training Loop so everything here should look pretty familiar now some of the small things that I added number one I added the ability to run on a GPU if you have it so if you have a GPU then you can this will use Cuda instead of just CPU and everything will be a lot more faster now when device becomes Cuda then we need to make sure that when we load the data we move it to device when we create the model we want
# to move uh the model parameters to device so as an example here we have the N an embedding table and it's got a weight inside it which stores the uh sort of lookup table so so that would be moved to the GPU so that all the calculations here happen on the GPU and they can be a lot faster and then finally here when I'm creating the context that feeds in to generate I have to make sure that I create it on the device number two what I introduced is uh the fact that here in the training Loop here I was just printing the um l.
# item inside the training Loop but this is a very noisy measurement of the current loss because every batch will be more or less lucky and so what I want to do usually um is uh I have an estimate loss function and the estimate loss basically then um goes up here and it averages up the loss over multiple batches so in particular we're going to iterate eval iter times and we're going to basically get our loss and then we're going to get the average loss for both splits and so this will be a lot less
# noisy so here when we call the estimate loss we're we're going to report the uh pretty accurate train and validation loss now when we come back up you'll notice a few things here I'm setting the model to evaluation phase and down here I'm resetting it back to training phase now right now for our model as is this doesn't actually do anything because the only thing inside this model is this uh nn. embedding and um this this um Network would behave both would behave the same in both evaluation mode and
# training mode we have no drop off layers we have no batm layers Etc but it is a good practice to Think Through what mode your neural network is in because some layers will have different Behavior Uh at inference time or training time and there's also this context manager torch up nograd and this is just telling pytorch that everything that happens inside this function we will not call do backward on and so pytorch can be a lot more efficient with its memory use because it doesn't have to store all the
# intermediate variables uh because we're never going to call backward and so it can it can be a lot more memory efficient in that way so also a good practice to tpy torch when we don't intend to do back propagation so right now this script is about 120 lines of code of and that's kind of our starter code I'm calling it b.p and I'm going to release it later now running this script gives us output in the terminal and it looks something like this it basically as I ran this code uh it was
# giving me the train loss and Val loss and we see that we convert to somewhere around 2.5 with the pyr model and then here's the sample that we produced at the end and so we have everything packaged up in the script and we're in a good position now to iterate on this okay so we are almost ready to start writing our very first self attention block for processing these uh tokens now before we actually get there I want to get you used to a mathematical trick that is used in the self attention inside a
# Transformer and is really just like at the heart of an an efficient implementation of self attention and so I want to work with this toy example to just get you used to this operation and then it's going to make it much more clear once we actually get to um to it uh in the script again so let's create a b BYT by C where BT and C are just 48 and two in the toy example and these are basically channels and we have uh batches and we have the time component and we have information at each point in the sequence so

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?
max_iters = 3000
eval_interval = 300
learning_rate = 1e-2
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embed = 32
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):#, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        #self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)
        self.token_embedding_table = nn.Embedding(vocab_size, n_embed)
        self.lm_head = nn.Linear(n_embed,vocab_size)

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        #logits = self.token_embedding_table(idx) # (B,T,C)
        tok_emb = self.token_embedding_table(idx) # (B,T,Cvocab_size
        logits = self.lm_head(tok_emb)
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

#model = BigramLanguageModel(vocab_size)
model = BigramLanguageModel()   
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# step 0: train loss 4.3886, val loss 4.3734
# step 300: train loss 2.5267, val loss 2.5399
# step 600: train loss 2.4998, val loss 2.5315
# step 900: train loss 2.4903, val loss 2.5085
# step 1200: train loss 2.4967, val loss 2.5128
# step 1500: train loss 2.4809, val loss 2.5020
# step 1800: train loss 2.4858, val loss 2.5149
# step 2100: train loss 2.4865, val loss 2.5000
# step 2400: train loss 2.4882, val loss 2.5127
# step 2700: train loss 2.5006, val loss 2.5117
#
# A:
# Wit min fush IUnonthefove thacke nd al INepe unco mid at IIfuries rye.
#
# Cis vedis to ctha dry chit MEOffis cebans ur rf y, ieve dse lathad f yive;
# Tharard il tos oulop ope martthor'ds id t RTEN:
# Tofavalx el r y, lat condin'macharus pes son:
# Cose;
# THesonthonde'
# THAnd ithi:
# LANalistarmuctimis to blllondedala!
#
# NG espro. hin g
# Fo d cheo.
# Asell sik thangs,-h
# TOrthathe mis trt HAnju
# Clyofflloutis mouroff veal'rali t aliole O:
# Sathanous wistrid dsthanullt, louqulthiseswen t hyoutelfietrduee ilais's

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?
max_iters = 3000
eval_interval = 300
learning_rate = 1e-2
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embed = 32
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):#, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        #self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)
        self.token_embedding_table = nn.Embedding(vocab_size, n_embed)
        self.position_embedding_table = nn.Embedding(block_size , n_embed)
        self.lm_head = nn.Linear(n_embed,vocab_size)

    def forward(self, idx, targets=None):
        B,T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        #logits = self.token_embedding_table(idx) # (B,T,C)
        tok_emb = self.token_embedding_table(idx) # (B,T,Cvocab_size
        pos_emb = self.position_embedding_table(torch.arange(T,device=device))
        x = tok_emb + pos_emb
        logits = self.lm_head(tok_emb)
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

#model = BigramLanguageModel(vocab_size)
model = BigramLanguageModel()   
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# step 0: train loss 4.3446, val loss 4.3516
# step 300: train loss 2.5223, val loss 2.5412
# step 600: train loss 2.4997, val loss 2.5250
# step 900: train loss 2.4873, val loss 2.5068
# step 1200: train loss 2.5039, val loss 2.5208
# step 1500: train loss 2.4795, val loss 2.5059
# step 1800: train loss 2.4886, val loss 2.5156
# step 2100: train loss 2.4907, val loss 2.5049
# step 2400: train loss 2.4883, val loss 2.5078
# step 2700: train loss 2.4986, val loss 2.5084
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 131
#     129 # generate from the model
#     130 context = torch.zeros((1, 1), dtype=torch.long, device=device)
# --> 131 print(decode(m.generate(context, max_new_tokens=500)[0].tolist()))
#
# Cell In[5], line 95, in BigramLanguageModel.generate(self, idx, max_new_tokens)
#      91 def generate(self, idx, max_new_tokens):
#      92     # idx is (B, T) array of indices in the current context
#      93     for _ in range(max_new_tokens):
#      94         # get the predictions
# ---> 95         logits, loss = self(idx)
#      96         # focus only on the last time step
#      97         logits = logits[:, -1, :] # becomes (B, C)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[5], line 78, in BigramLanguageModel.forward(self, idx, targets)
#      75 # idx and targets are both (B,T) tensor of integers
#      76 #logits = self.token_embedding_table(idx) # (B,T,C)
#      77 tok_emb = self.token_embedding_table(idx) # (B,T,Cvocab_size
# ---> 78 pos_emb = self.position_embedding_table(torch.arange(T,device=device))
#      79 x = tok_emb + pos_emb
#      80 logits = self.lm_head(tok_emb)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\sparse.py:192, in Embedding.forward(self, input)
#     191 def forward(self, input: Tensor) -> Tensor:
# --> 192     return F.embedding(
#     193         input,
#     194         self.weight,
#     195         self.padding_idx,
#     196         self.max_norm,
#     197         self.norm_type,
#     198         self.scale_grad_by_freq,
#     199         self.sparse,
#     200     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\functional.py:2546, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2540     # Note [embedding_renorm set_grad_enabled]
#    2541     # XXX: equivalent to
#    2542     # with torch.no_grad():
#    2543     #   torch.embedding_renorm_
#    2544     # remove once script supports set_grad_enabled
#    2545     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2546 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
       # wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.sa_head = Head(n_embd)
        #self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        #self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        #x = self.blocks(x) # (B,T,C)
        #x = self.ln_f(x) # (B,T,C)
        x = self.sa_head(x)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.022721 M parameters
# step 0: train loss 4.1833, val loss 4.1869
# step 100: train loss 3.0050, val loss 3.0363
# step 200: train loss 2.8227, val loss 2.8392
# step 300: train loss 2.7148, val loss 2.7341
# step 400: train loss 2.6388, val loss 2.6461
# step 500: train loss 2.5939, val loss 2.5951
# step 600: train loss 2.5448, val loss 2.5488
# step 700: train loss 2.5140, val loss 2.5246
# step 800: train loss 2.4861, val loss 2.4868
# step 900: train loss 2.4649, val loss 2.4787
# step 1000: train loss 2.4572, val loss 2.4733
# step 1100: train loss 2.4415, val loss 2.4440
# step 1200: train loss 2.4313, val loss 2.4354
# step 1300: train loss 2.4174, val loss 2.4277
# step 1400: train loss 2.4078, val loss 2.4216
# step 1500: train loss 2.4014, val loss 2.4198
# step 1600: train loss 2.4052, val loss 2.4133
# step 1700: train loss 2.3900, val loss 2.4004
# step 1800: train loss 2.3892, val loss 2.4049
# step 1900: train loss 2.3843, val loss 2.3943
# step 2000: train loss 2.3771, val loss 2.4044
# step 2100: train loss 2.3815, val loss 2.3997
# step 2200: train loss 2.3730, val loss 2.3941
# step 2300: train loss 2.3684, val loss 2.3957
# step 2400: train loss 2.3656, val loss 2.3855
# step 2500: train loss 2.3761, val loss 2.3867
# step 2600: train loss 2.3685, val loss 2.3869
# step 2700: train loss 2.3675, val loss 2.3797
# step 2800: train loss 2.3581, val loss 2.3787
# step 2900: train loss 2.3492, val loss 2.3727
# step 3000: train loss 2.3640, val loss 2.3790
# step 3100: train loss 2.3557, val loss 2.3775
# step 3200: train loss 2.3497, val loss 2.3663
# step 3300: train loss 2.3488, val loss 2.3745
# step 3400: train loss 2.3403, val loss 2.3683
# step 3500: train loss 2.3517, val loss 2.3709
# step 3600: train loss 2.3502, val loss 2.3773
# step 3700: train loss 2.3488, val loss 2.3680
# step 3800: train loss 2.3368, val loss 2.3651
# step 3900: train loss 2.3317, val loss 2.3666
# step 4000: train loss 2.3335, val loss 2.3656
# step 4100: train loss 2.3330, val loss 2.3621
# step 4200: train loss 2.3316, val loss 2.3637
# step 4300: train loss 2.3324, val loss 2.3597
# step 4400: train loss 2.3231, val loss 2.3640
# step 4500: train loss 2.3245, val loss 2.3618
# step 4600: train loss 2.3231, val loss 2.3510
# step 4700: train loss 2.3270, val loss 2.3552
# step 4800: train loss 2.3237, val loss 2.3469
# step 4900: train loss 2.3335, val loss 2.3506
# step 4999: train loss 2.3225, val loss 2.3451
#
# Nicut be thatus,
# YCouth Noucced wictoh the lilany cbor ot asovice soome over sfiflef souce.
#
# MI dis tonert min bestt wawir-nt goun cowsod one geld shur dotithy hrands you dses to thal mathird this bok's.
# Feneceangerer ber the.
#
# Hauspe I pe hirth
# Pi, me p irshat orot hainck, me yoke avift,
# Liut bor tur;
# Fry;
# o thor'ld yathy my chat,
# I thait,
# Teschit ng es tam, fin.
#
# Thivece,
# Par.
#
# Whe.
#
# Yo tho mino tun the wof
# yof tsh I ptincofut to od heru psh peer ts lm vitor. Coodor, lor brene oure hwiginsu my od wor p tene bium ty ser.
# BO Eig--
# Om; te nort, tene anis Ald:
# Y onds Bous thons! O dlot the bere nwing's thinllo, mro, I ond bend de mach git, ot.
#
# Hincon?
#
# Caris doul swou hunt chungur I avores chatirdedm and
# Tour
# Hadn nocold--di-br omentl em fo-t ther tathut col wis
# lat, on ofuamine thaclod bes! An:
# JHou I'sl ow ther bathtoel thuge rowe yo wor
# Fal encst me; Gs atilel ser wisall set cang to measis
# Hes utr bis beg, rif briseto,
# Pes po imn anft aldu who cke, ay kit star tir yef ow cilout ber dedrerre ts ndisatr-poh arcikeewesa pelenen ss;
# Thew my
# Whif he aty itho?
#
# Whe ORIAD elelodo ithistt tng, bawne,
# Be
# Ad Rout hre wano nt our fr th hous mot do itrake! Gn athim scke llk.
#
# Lordesare pine thal ne,
# Thowleve,
# Y omeathas to
# ns Pucrobllif corndiver ve. And I:
# A
# sen at, ond stheatebret, the forr
# Whait ge ks, she I GNow ly hears is ise hy bllecat whe mn,
# LAr the I ugh bis ats har uenawris?TRe be
# GERTE RCHIS: RlI fros and toum, come te bul misein aiptat
# t mbe fre sise mvast he Fr?
#
# Ars nd,
# Youp is the ly Pouns?
#
# I I ntouspel, s yu.
#
# BUI moprer whe nowm st sll ck you ind, athrem Par I'tll thing bang aulcal ppe thathit hi cll thiths t the.
#
# If yr tewis mat thee ficre told me I mucepl; hanot me th myoverow, olther mey pris wite, tofuanowl theabrok.
#
# Ty.
#  Wom, why hor pre pre te werist gand;
# Mater ther, rorway che su'd-'s whin.
#
# Rporord.
#
# A marcor thy ty cere te lll aven tepl;
# h wasthen
# Abou pango won braricmy, nid tis lwhile.
#
# Whe,
# Paver hat to spatwh se
# GOPRUwithow fr dwe:
# h
# Cerit h

# %%
# Multi-Head Attention
# 	• Multi-head attention runs multiple self-attention heads in parallel, each looking at the sequence from different learned perspectives.
# 	• Outputs of all heads are concatenated and projected back to the embedding dimension.
# 	• This allows the model to capture diverse patterns and relationships simultaneously.
# 	• Adding multiple heads improves validation loss and model expressivity.

from IPython.display import Image, display
display(Image(filename='Mutli-head attention.png'))
display(Image(filename='scaledprod2.png'))

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
       # wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        # self.proj = nn.Linear(n_embd, n_embd)
        # self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return torch.cat([h(x) for h in self.heads], dim=-1)
        # out = torch.cat([h(x) for h in self.heads], dim=-1)
        # out = self.dropout(self.proj(out))
        # return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.sa_heads = MultiHeadAttention(4,n_embd//4)
        #self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        #self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        #x = self.blocks(x) # (B,T,C)
        #x = self.ln_f(x) # (B,T,C)
        x = self.sa_heads(x)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.022721 M parameters
# step 0: train loss 4.1853, val loss 4.1873
# step 100: train loss 2.9747, val loss 3.0009
# step 200: train loss 2.7518, val loss 2.7661
# step 300: train loss 2.6591, val loss 2.6798
# step 400: train loss 2.6182, val loss 2.6269
# step 500: train loss 2.5930, val loss 2.5930
# step 600: train loss 2.5546, val loss 2.5621
# step 700: train loss 2.5342, val loss 2.5396
# step 800: train loss 2.5064, val loss 2.5136
# step 900: train loss 2.4835, val loss 2.4996
# step 1000: train loss 2.4670, val loss 2.4792
# step 1100: train loss 2.4416, val loss 2.4394
# step 1200: train loss 2.4153, val loss 2.4185
# step 1300: train loss 2.3911, val loss 2.3989
# step 1400: train loss 2.3677, val loss 2.3773
# step 1500: train loss 2.3531, val loss 2.3675
# step 1600: train loss 2.3427, val loss 2.3498
# step 1700: train loss 2.3126, val loss 2.3262
# step 1800: train loss 2.3064, val loss 2.3227
# step 1900: train loss 2.2902, val loss 2.3050
# step 2000: train loss 2.2730, val loss 2.3085
# step 2100: train loss 2.2664, val loss 2.2947
# step 2200: train loss 2.2546, val loss 2.2829
# step 2300: train loss 2.2471, val loss 2.2824
# step 2400: train loss 2.2385, val loss 2.2662
# step 2500: train loss 2.2414, val loss 2.2608
# step 2600: train loss 2.2319, val loss 2.2587
# step 2700: train loss 2.2213, val loss 2.2457
# step 2800: train loss 2.2091, val loss 2.2372
# step 2900: train loss 2.1941, val loss 2.2333
# step 3000: train loss 2.1984, val loss 2.2304
# step 3100: train loss 2.1888, val loss 2.2269
# step 3200: train loss 2.1765, val loss 2.2140
# step 3300: train loss 2.1735, val loss 2.2160
# step 3400: train loss 2.1640, val loss 2.2100
# step 3500: train loss 2.1684, val loss 2.2088
# step 3600: train loss 2.1632, val loss 2.2134
# step 3700: train loss 2.1637, val loss 2.2017
# step 3800: train loss 2.1463, val loss 2.1959
# step 3900: train loss 2.1381, val loss 2.1991
# step 4000: train loss 2.1378, val loss 2.1937
# step 4100: train loss 2.1327, val loss 2.1855
# step 4200: train loss 2.1260, val loss 2.1871
# step 4300: train loss 2.1218, val loss 2.1786
# step 4400: train loss 2.1151, val loss 2.1854
# step 4500: train loss 2.1128, val loss 2.1750
# step 4600: train loss 2.1138, val loss 2.1724
# step 4700: train loss 2.1110, val loss 2.1653
# step 4800: train loss 2.1058, val loss 2.1636
# step 4900: train loss 2.1138, val loss 2.1655
# step 4999: train loss 2.0976, val loss 2.1554
#
# Sicut be that some orth No ace donetsh!-3 I flare cbord
# Bmay so shalll be lord if your oneg
# Apl dis conertumins: sto wawit-ming.
# NAULISoMGone gall shur do ith theries you dres to noff make ownt is be thism;
# INUS:
# Seracle that. Bas one I priss thas stingreirshoum, comm,
# W-RIUS:
#
# Abet-oum tupiow ber tho; shy; of corde;
# I My mut chat, I dosto, we; share Iew tam, win.
#
# This cratthout the of forcome.
#
# Pren the wordy frts hat thaum mus? bod he uppshapeece
# stlictimpres bodore'ld sharne ouse his ins of you how parthe bith these,
# Nod Eiend to ste hort, link ans to wos mandset of the shaver.
#
# BULIZELLA:
# Ther's to now thir. CIT:
# The would mach gin, ot.
# Forncomece, mpeed plosstly cotlid ut avind dres chatir hempay,
# Tose nownen.
#
# BUS:
# But tomentleem no-t ther.'
# Iflescomuld nlet, on to amake thad he beld to bescus smy of ther!
# Butt-eld witch, what it a
# Fall hess my my to ill ried withis share,
#
# As wilast sartiut fors ien, you bris to an would on a fre wauld,
# When's you to lare. Whath ow citous be
# bledrersublssuckeatrupohe wo somoosa pedenen sw;
# To word
# Whifhim and lond? I the I puter'lodo itdistt:
# ng, bawne incoull lod the wast nad her thou hous moter
# tirceat! Gn sthe incces lowgrabrienar whink thallem,
# Thowle thon ler,
# Ras couns Pece brois comnend cjonight thous
# sens thuringst.'
# Tibrets to sharr
# Wothe gep fars.
#
# I'll theathears is if farisleece frof mow
# The the cought-he gus har upieir,
# saye be wis a bileep sly frestand to may of the bud ming craip: ith mpitfur sipedscast he Fr?
#
# Arozes, dare in the low ones?
#
# I I nt but ber wichim.
#
# Pare, res be prm sre.
#
# Gow you ince apprelke, of thust ing band aulcall
# peating gir inclorth Ogs y the comusor tewill awet he wich I nt
# To bre mmep morke a my thou bverows olt
# Sat:
# Hour shar
# NCELORED:
# But peabrokgithy.
#  I m of yu hat he pren:
# Buss; arly dok.
#
# BEL:
# Nut roveay che so'd-wy you.
#
# ARD:
# Wothucghe, conesty thiced'd will tamen to thell
# Tathen
# Abod parko won braclim their to dowhe ress?
#
# LAPUTULI:
# Your sparweld thes; whe mx from by ptaprit h

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
       # wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        # self.proj = nn.Linear(n_embd, n_embd)
        # self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return torch.cat([h(x) for h in self.heads], dim=-1)
        # out = torch.cat([h(x) for h in self.heads], dim=-1)
        # out = self.dropout(self.proj(out))
        # return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            # nn.Linear(4 * n_embd, n_embd),
            # nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.sa_heads = MultiHeadAttention(4,n_embd//4)
        #self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        #self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.ffwd =  FeedFoward(n_embd)
        #self.lm_head = nn.Linear(n_embd, vocab_size)
        self.lm_head = nn.Linear(n_embd*4, vocab_size)
        #self.lm_head = nn.Linear(256, 65)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        #x = self.blocks(x) # (B,T,C)
        #x = self.ln_f(x) # (B,T,C)
        x = self.sa_heads(x)
        x = self.ffwd(x)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.051841 M parameters
# step 0: train loss 4.1571, val loss 4.1594
# step 100: train loss 2.8409, val loss 2.8619
# step 200: train loss 2.6363, val loss 2.6414
# step 300: train loss 2.5642, val loss 2.5766
# step 400: train loss 2.5165, val loss 2.5142
# step 500: train loss 2.4724, val loss 2.4835
# step 600: train loss 2.4225, val loss 2.4195
# step 700: train loss 2.3813, val loss 2.3849
# step 800: train loss 2.3344, val loss 2.3475
# step 900: train loss 2.2994, val loss 2.2991
# step 1000: train loss 2.2607, val loss 2.2757
# step 1100: train loss 2.2111, val loss 2.2320
# step 1200: train loss 2.2027, val loss 2.2294
# step 1300: train loss 2.1670, val loss 2.1954
# step 1400: train loss 2.1496, val loss 2.1872
# step 1500: train loss 2.1350, val loss 2.1749
# step 1600: train loss 2.1152, val loss 2.1599
# step 1700: train loss 2.0896, val loss 2.1399
# step 1800: train loss 2.0771, val loss 2.1389
# step 1900: train loss 2.0744, val loss 2.1261
# step 2000: train loss 2.0504, val loss 2.1245
# step 2100: train loss 2.0377, val loss 2.1140
# step 2200: train loss 2.0285, val loss 2.1116
# step 2300: train loss 2.0246, val loss 2.0937
# step 2400: train loss 2.0083, val loss 2.0820
# step 2500: train loss 1.9884, val loss 2.0750
# step 2600: train loss 1.9909, val loss 2.0729
# step 2700: train loss 1.9773, val loss 2.0682
# step 2800: train loss 1.9620, val loss 2.0640
# step 2900: train loss 1.9679, val loss 2.0596
# step 3000: train loss 1.9611, val loss 2.0522
# step 3100: train loss 1.9484, val loss 2.0449
# step 3200: train loss 1.9349, val loss 2.0449
# step 3300: train loss 1.9229, val loss 2.0235
# step 3400: train loss 1.9175, val loss 2.0161
# step 3500: train loss 1.9034, val loss 2.0225
# step 3600: train loss 1.9042, val loss 2.0137
# step 3700: train loss 1.8940, val loss 2.0182
# step 3800: train loss 1.8920, val loss 2.0150
# step 3900: train loss 1.8997, val loss 2.0198
# step 4000: train loss 1.8784, val loss 2.0070
# step 4100: train loss 1.8765, val loss 2.0018
# step 4200: train loss 1.8796, val loss 1.9996
# step 4300: train loss 1.8772, val loss 1.9882
# step 4400: train loss 1.8711, val loss 1.9981
# step 4500: train loss 1.8652, val loss 1.9965
# step 4600: train loss 1.8631, val loss 1.9966
# step 4700: train loss 1.8484, val loss 1.9954
# step 4800: train loss 1.8521, val loss 1.9952
# step 4900: train loss 1.8424, val loss 1.9833
# step 4999: train loss 1.8436, val loss 1.9925
#
# Wiscausone then him too stand hirshallord my,
# Wh that your dout tupite ber tho;
# Friumon, thou; I whim, Wriar, I dow offiescal, to exwar;
# Whip.
#
# KING BOUCESTER:
# Second, thou thou sont he cany fits hit that five?' of then prabperincommannity-say, dor playse!
#
# CORIOLANUE:
# What my be him my neve un the some dowith sain thee to to nexa!
#
# PAGURICHARD II:
# For shille dritfelt be thy sup's to now to riithe gree.
# Warwill I cit, of, your couce
# crow, tulds, lordstich and vighad as charibeced and
# To For Godn.
#
# PLING EDWARD:
# Hiter! O's ther.
# Comudscommaninly and Good eare that hear,
# And sto cursemill bod theathtee diess soole you,
# This veress my for atils, sea,
# Civallsel ead with taking deavaing of in your brise, 'tishould me a frial unward,
# Sit:
# Shou hopur.
# Whath o's it
# Ber'd
# beren, the soundeat spoher come woran's I wast are we my pesputh any lond?
#
# WARWICIUS OF AUMBER:
# Twithen tor woe, ar
# As flaid we wasome do trust a sous moth it
# Istate Gnobled iscire lead hom.
#
# MONTOLYORK:
# A whad howle thand hear
# fortuess upor balifend, did crow, that lrows now jusid sone: ibrothink ther thear
# Whe knows.
#
# ISANLY:
# Whipars is is farible catils, my tone the crutition, this fournessiastee be wish lif, Spaily friess with may of with we mise crain: Why lordfuree seescause.
# Mare, brozed, fare is is the do friencess wibst be's thought Pare,
# Lord growmy?
#
# HENRY:
# It nible at the his but up ding brove ulcal preath
# Which is litth the rea, I amfsom tea,
# As with thy crut not me arm. Ta Edward comish your pois of York know! sham, my det
# To lovess:
# I gived.
# And to to his provere thater; are your ther the her pray cord your's which arporowl,
# Is mill his yoursed 'tie deat me and to hisess enter bepfulost her,
# And you fortuadl!
# Thensser drid consuts of Rich: I know 'tishose tor by hippy his for danot the thou lord Quetle andiess wardy.
# Whongs, i' such aboy, but shave mese for this
# a'd the is fromy of NlA:
# Hlame the thed fre:
# Bovisidtest some slace, I haver'd:
# My coness, disirs:
# No, a friese not the brover, Do

# %%
#self.lm_head = nn.Linear(n_embd, vocab_size)  --> not working above 
        self.lm_head = nn.Linear(256, 65)

# The recurring error

# text
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (512x256 and 64x65)
# means that in your forward method, the tensor x fed into self.lm_head has a last dimension of 256, but self.lm_head expects an input with 64 features.

# Detailed diagnosis and solution steps:
# Mismatch of feature dimensions:

# Your input tensor x to self.lm_head inside BigramLanguageModel.forward has shape (512, 256) — so batch size is 512 and feature size is 256.

# Your linear layer self.lm_head is defined with weight dimensions (64, 65), where 64 is the input feature size, 65 is the output feature size (likely vocab size).

# Where 256 vs 64 incompatibility comes from:

# The 256 features arrive from the preceding layer, for example self.ffwd(x) or self.sa_heads(x).

# But the final linear layer expects input features of size 64 (in_features=64).

# Fix:
# Align the input feature dimension of the linear layer self.lm_head to match the output dimension of the previous layer, which is 256 here.

# Example fix — change definition of lm_head:
# If your vocabulary size is 65 and your hidden size output by previous layers is 256, then:

# %%
 # Residual Connections and Normalization
# 	# • Residual (skip) connections add the input of a sub-layer to its output, 
# facilitating gradient flow during backpropagation anbd easing training of deep networks.
# 	# • Layer normalization (layer norm) normalizes activations across the feature dimension
# for each token independently, stabilizing training.
# 	# • Pre-LayerNorm architecture applies normalization before each sub-layer 
# (attention or feed-forward), improving convergence.
# 	# • Adding residual connections and layer norm reduces training loss and stabilizes deeper models.
from IPython.display import Image, display
display(Image(filename='rl1.png'))
display(Image(filename='rl2.png'))

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
       # wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        #return torch.cat([h(x) for h in self.heads], dim=-1)
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            # nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        #self.ln1 = nn.LayerNorm(n_embd)
        #self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        #x = x + self.sa(self.ln1(x))
        #x = x + self.ffwd(self.ln2(x))
        x = x + self.sa(x)
        x = x + self.ffwd(x)
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(
                 Block(n_embd , n_head=4),
                 Block(n_embd , n_head=4),
                 Block(n_embd , n_head=4),
                 )
        
        #self.sa_heads = MultiHeadAttention(4,n_embd//4)
        #self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        #self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        #self.ffwd =  FeedFoward(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
        #self.lm_head = nn.Linear(256, 65)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        #x = self.ln_f(x) # (B,T,C)
        #x = self.sa_heads(x)
        #x = self.ffwd(x)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.159041 M parameters
# step 0: train loss 4.7325, val loss 4.7186
# step 100: train loss 2.6192, val loss 2.6266
# step 200: train loss 2.4963, val loss 2.5043
# step 300: train loss 2.3942, val loss 2.4146
# step 400: train loss 2.3264, val loss 2.3546
# step 500: train loss 2.2822, val loss 2.3023
# step 600: train loss 2.2358, val loss 2.2695
# step 700: train loss 2.1785, val loss 2.2160
# step 800: train loss 2.1591, val loss 2.1864
# step 900: train loss 2.1203, val loss 2.1672
# step 1000: train loss 2.0878, val loss 2.1325
# step 1100: train loss 2.0571, val loss 2.1087
# step 1200: train loss 2.0227, val loss 2.0950
# step 1300: train loss 2.0084, val loss 2.0761
# step 1400: train loss 1.9786, val loss 2.0511
# step 1500: train loss 1.9584, val loss 2.0300
# step 1600: train loss 1.9509, val loss 2.0318
# step 1700: train loss 1.9314, val loss 2.0295
# step 1800: train loss 1.9256, val loss 2.0262
# step 1900: train loss 1.8984, val loss 2.0169
# step 2000: train loss 1.9028, val loss 2.0090
# step 2100: train loss 1.8704, val loss 1.9937
# step 2200: train loss 1.8628, val loss 1.9948
# step 2300: train loss 1.8546, val loss 1.9832
# step 2400: train loss 1.8443, val loss 1.9920
# step 2500: train loss 1.8353, val loss 1.9689
# step 2600: train loss 1.8199, val loss 1.9591
# step 2700: train loss 1.8188, val loss 1.9608
# step 2800: train loss 1.8077, val loss 1.9500
# step 2900: train loss 1.7981, val loss 1.9125
# step 3000: train loss 1.8128, val loss 1.9458
# step 3100: train loss 1.7854, val loss 1.9344
# step 3200: train loss 1.7909, val loss 1.9362
# step 3300: train loss 1.7782, val loss 1.9287
# step 3400: train loss 1.7711, val loss 1.9121
# step 3500: train loss 1.7689, val loss 1.9279
# step 3600: train loss 1.7601, val loss 1.9110
# step 3700: train loss 1.7406, val loss 1.9121
# step 3800: train loss 1.7456, val loss 1.9139
# step 3900: train loss 1.7301, val loss 1.8872
# step 4000: train loss 1.7293, val loss 1.8730
# step 4100: train loss 1.7261, val loss 1.8823
# step 4200: train loss 1.7292, val loss 1.8993
# step 4300: train loss 1.7212, val loss 1.8925
# step 4400: train loss 1.7189, val loss 1.8907
# step 4500: train loss 1.7064, val loss 1.8876
# step 4600: train loss 1.7070, val loss 1.8773
# step 4700: train loss 1.7056, val loss 1.8717
# step 4800: train loss 1.7037, val loss 1.8658
# step 4900: train loss 1.7043, val loss 1.8722
# step 4999: train loss 1.6987, val loss 1.8678
#
# That damber, all his worth it him not thee tabled in in the prace whencle ft the day?
# No, here oof the marker chich
# Come, and have a book Angelo. I lies well are man: apbut what that indeop all
# doub of a larry enemile, wiful; my lamn:
# Do she
# As I be a father the's but to his king:
# Rize, you name, let dother'll greence duke
# by tell of me thusbuod wicks,
# Heresings, rewich and by mine his so that,
# Is I not wouldld feech that pluck a laple a be
# DaLid.
# Chater, how doods dischry's abperfous argragleof the points happhim.
# Lust face nead your our hims:
# Which's dispoce us
# Besome forble a mook, foull
# Sun the is my a genech he hear hims shall not o'er
# ander thy hard disgords: ressat that them
# one your not roc
# Of 'ssuch hast Annot sad nurse a fried,
# But coelld death that not the soReT but to briege;
# Our brothe therefore, this I will it.
#
# LAXEONDW:
# Firshath you rant?
# He hear achce apposse, hear thy of the brach found boreful them
# Look Lrofher would, gief that is thereas,
# Why, then I farce, and but you hath feartth
# I that hath we; for me ederposed,
# She fool dinkeds lightats said the ally blook France.
#
# KING RICHARD IIII:
# Weare make is as gracest umbrouna, and grant opcitied,
# And an my bettable is the purpt can
# But assot us have rant him;
# My fatt reforage nat so there bohd-
# And fuce, lie at which, I reish,
# beard I call earinc! I'll we garth to not leargess eals.
#
# First Sed Lort: him,
# Why, hoth in then, that to purght thee.
# A carcudles I
# quitign con he father, our listrumely sir, I tear to him whilf's it elst?
# Heel, goed me hearterity.
#
# ESCALULET:
# So call other as bell,
# Las blour greatter forture-Bastruth:
# That was his diecely.
# That that wat rexhalli's bornon Wiles
# Fhereart night it lo are his husbond,
# Leake if him if.
#
# KING RICHARD IIIIII:
# Are it you should couses bear-diect the child--
# Ladant sheps in, for tworded the caill will dear
# Thd
# Mraker meels-daster it?
#
# JULIETZABETH:
# Sere all to erears lect in perress
# the her if them my lord,
# To the we fier mereat my larks your like.
# Ne

# %%
#layernorm
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
       # wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        #return torch.cat([h(x) for h in self.heads], dim=-1)
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            # nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        #x = x + self.sa(x)
        #x = x + self.ffwd(x)
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(
                 Block(n_embd , n_head=4),
                 Block(n_embd , n_head=4),
                 Block(n_embd , n_head=4),
                 )
        
        #self.sa_heads = MultiHeadAttention(4,n_embd//4)
        #self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        #self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        #self.ffwd =  FeedFoward(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
        #self.lm_head = nn.Linear(256, 65)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        #x = self.ln_f(x) # (B,T,C)
        #x = self.sa_heads(x)
        #x = self.ffwd(x)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.159809 M parameters
# step 0: train loss 4.6593, val loss 4.6446
# step 100: train loss 2.6417, val loss 2.6521
# step 200: train loss 2.5172, val loss 2.5299
# step 300: train loss 2.4334, val loss 2.4532
# step 400: train loss 2.3602, val loss 2.3813
# step 500: train loss 2.3122, val loss 2.3259
# step 600: train loss 2.2670, val loss 2.2923
# step 700: train loss 2.2189, val loss 2.2469
# step 800: train loss 2.1998, val loss 2.2130
# step 900: train loss 2.1572, val loss 2.1866
# step 1000: train loss 2.1317, val loss 2.1584
# step 1100: train loss 2.1023, val loss 2.1360
# step 1200: train loss 2.0739, val loss 2.1284
# step 1300: train loss 2.0576, val loss 2.1005
# step 1400: train loss 2.0269, val loss 2.0759
# step 1500: train loss 2.0066, val loss 2.0558
# step 1600: train loss 1.9958, val loss 2.0552
# step 1700: train loss 1.9690, val loss 2.0424
# step 1800: train loss 1.9696, val loss 2.0456
# step 1900: train loss 1.9501, val loss 2.0391
# step 2000: train loss 1.9499, val loss 2.0252
# step 2100: train loss 1.9182, val loss 2.0173
# step 2200: train loss 1.9033, val loss 2.0124
# step 2300: train loss 1.8974, val loss 2.0041
# step 2400: train loss 1.8837, val loss 2.0069
# step 2500: train loss 1.8792, val loss 1.9933
# step 2600: train loss 1.8575, val loss 1.9774
# step 2700: train loss 1.8556, val loss 1.9845
# step 2800: train loss 1.8364, val loss 1.9718
# step 2900: train loss 1.8331, val loss 1.9445
# step 3000: train loss 1.8324, val loss 1.9550
# step 3100: train loss 1.8173, val loss 1.9511
# step 3200: train loss 1.8176, val loss 1.9519
# step 3300: train loss 1.8023, val loss 1.9461
# step 3400: train loss 1.7963, val loss 1.9312
# step 3500: train loss 1.7865, val loss 1.9343
# step 3600: train loss 1.7857, val loss 1.9361
# step 3700: train loss 1.7693, val loss 1.9365
# step 3800: train loss 1.7647, val loss 1.9256
# step 3900: train loss 1.7530, val loss 1.9068
# step 4000: train loss 1.7543, val loss 1.8966
# step 4100: train loss 1.7450, val loss 1.8998
# step 4200: train loss 1.7417, val loss 1.9065
# step 4300: train loss 1.7401, val loss 1.9045
# step 4400: train loss 1.7370, val loss 1.9000
# step 4500: train loss 1.7277, val loss 1.8987
# step 4600: train loss 1.7239, val loss 1.8834
# step 4700: train loss 1.7171, val loss 1.8771
# step 4800: train loss 1.7202, val loss 1.8856
# step 4900: train loss 1.7179, val loss 1.8849
# step 4999: train loss 1.7143, val loss 1.8782
#
# That drames, and his worth irftley once:
# Cy't,
# Couit in EDWIS Saling other the I say?
#
# AUTZABETH:
# This maje.
#
# CAPULET:
# Say, to set you 'Forful, this ies well a sidagnice it.
#
# COMPEY:
# Mideop all to-more a lad your thape:
# My shall.
#
# MOREONI:
# Go, care:
# I am, frreenger that for you and mwars burne roke steek.
# I'll givent upon ful teep on me.
#
# GLOUCESET:
# I,
# Meads all, rewich and prompoly,
# Wo that heaving, be wouldlay your Wargelf
# Ap a lappet by himsid.
#
# CORTIOLANUS:
# I hear chaple, by senciler that of the pray
# bless, deart of King neal your our himsel,
# These with for thing dever blour acch,
# Against he hands, sir:
# Yorch yes I copers shall not once
# at prichinner this obroble, wat follow spirs.
#
# FRIAL:
# Whan
# Of 'Tis Bother And:
# As monurse are frience'l tell preay, toue, I is let.
#
# TRUMIOLAULEY:BULANULANE:
# Fort, myse.
#
# eCKINGIO:
# On:
# God may to drow, my they here: baret, my gince of thee,
# But Ekp too the brant foubled: If of thou our hrefer? would, goe:
# He's is there yous, pettly the from thy but you housse
# Hents I two not fort; for me eneed!'!
# mone the cursofer:
# Browell, so detch ally 'll worsend Orwards a hece,
# His my larged bour this farest umprouna, and grient.
# To it my best proed to bless, the purrice in the shouldly mert'd,
# Lour hards this forse, naths death:
# Moht Xopesful hast death of Andorsirit,
# Hate I quacce of the bust this which not leargess eals.
# I bett, no that jurtome: the in creamen,
# And thou to hence the can stoles,
# And mine con he father, ourmy
# Were alles I thine: be thir wear 'Roperel
# OXI up my held princeaveit concerougbider of aly of the adoul this banine
# To-fore hands over so the is fell, my lords, lept mat the lord?
#
# DOKE VINCENTES:
# With what
# In the of to the are hust Lark: no me rumet nows!
#
# GRIANLAULIO:
# The hath make words, bost balts
# All Bother to his not you art
# As just belace'd worlaint.
#
# CORHARNIUS:
# In thad
# My larde to that is Greech's hible that I guarghts epracer
# Which wifer thus resbuling my?
#
# Shall;
# Condirrule of dea, art my lords your like.
# Ne

# %%
#layernorm
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
# batch_size = 16 # how many independent sequences will we process in parallel?
# block_size = 32 # what is the maximum context length for predictions?
# max_iters = 5000
# eval_interval = 100
# learning_rate = 1e-3
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# eval_iters = 200
# n_embd = 64
# n_head = 4
# n_layer = 4
# dropout = 0.0



batch_size = 64 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 3e-4
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 384
n_head = 6
n_layer = 6
dropout = 0.2

# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
       # wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        #return torch.cat([h(x) for h in self.heads], dim=-1)
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        #x = x + self.sa(x)
        #x = x + self.ffwd(x)
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        # self.blocks = nn.Sequential(
        #          Block(n_embd , n_head=4),
        #          Block(n_embd , n_head=4),
        #          Block(n_embd , n_head=4),
        #          )
        
        #self.sa_heads = MultiHeadAttention(4,n_embd//4)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        #self.ffwd =  FeedFoward(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
        #self.lm_head = nn.Linear(256, 65)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        #x = self.ln_f(x) # (B,T,C)
        #x = self.sa_heads(x)
        #x = self.ffwd(x)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 10.788929 M parameters

# %%
#dropout paper https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
display(Image(filename='dropout.png'))

# %%
#final code 

import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
